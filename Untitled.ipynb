# %%
import xarray as xr

# %%
xr.open_dataset('data/lyapunov1.nc')
# Out:
# <xarray.Dataset>
# Dimensions:                        (a: 130, l: 90, x: 10, y: 10)
# Coordinates:
#   * a                              (a) float64 0.7 0.71 0.72 ... 1.97 1.98 1.99
#   * l                              (l) float64 0.1 0.11 0.12 ... 0.97 0.98 0.99
#   * x                              (x) float64 -10.0 -7.778 ... 7.778 10.0
#   * y                              (y) float64 -10.0 -7.778 ... 7.778 10.0
# Data variables:
#     __xarray_dataarray_variable__  (x, y, l, a) float64 ...
